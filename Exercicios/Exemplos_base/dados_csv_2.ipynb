# %% [markdown]
# # Analise de dados CSV (Comma-separated values)
#
# * Arquivos de texto que faz ordenação dos dados numa linha, separando os valores por virgulas.
# * Nesta seção iremos trabalhar com o pandas

# %%
# a forma mais comum de chamar o pandas
import pandas as pd

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/georgynio/Envs/python_aulas/lib/python3.10/site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /home/georgynio/Envs/python_aulas/lib/python3.10/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/georgynio/Envs/python_aulas/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /home/georgynio/Envs/python_aulas/lib/python3.10/site-packages (from pandas) (1.23.3)
# Requirement already satisfied: six>=1.5 in /home/georgynio/Envs/python_aulas/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ## Se tivermos dados e precisamos utilizar algumas funções do Pandas
#
# Precisamos do seguinte:
# * dicionario, listas
# * pandas
#
# A estrutura de um DataFrame:
#
# <img src="./dataframe.webp" width="800">

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# ## Carregando um arquivo CSV num DataFrame:

# %%
df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv')
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1253, in TextFileReader.read(self, nrows)
#    1251 nrows = validate_integer("nrows", nrows)
#    1252 try:
# -> 1253     index, columns, col_dict = self._engine.read(nrows)
#    1254 except Exception:
#    1255     self.close()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 3, saw 17

# %%
df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv', skiprows=1, delimiter=';')

# %%
df.head()
# Out:
#          Data  Hora (UTC) Temp. Ins. (C) Temp. Max. (C) Temp. Min. (C)  \
# 0  01/10/2019         100           20,9           21,0           20,7
# 1  01/10/2019         200           20,6           21,0           20,5
# 2  01/10/2019         300           20,0           20,7           20,0
# 3  01/10/2019         400           20,0           20,2           20,0
# 4  01/10/2019         500           19,9           20,0           19,9
#
#   Umi. Ins. (%) Umi. Max. (%) Umi. Min. (%) Pto Orvalho Ins. (C)  \
# 0          95,0          96,0          94,0                 20,1
# 1          96,0          96,0          95,0                 19,9
# 2          96,0          96,0          96,0                 19,4
# 3          96,0          96,0          96,0                 19,3
# 4          95,0          96,0          95,0                 19,1
#
#   Pto Orvalho Max. (C) Pto Orvalho Min. (C) Pressao Ins. (hPa)  \
# 0                 20,2                 19,9             1014,7
# 1                 20,2                 19,8             1015,1
# 2                 20,0                 19,3             1014,9
# 3                 19,6                 19,3             1014,5
# 4                 19,3                 19,1             1014,0
#
#   Pressao Max. (hPa) Pressao Min. (hPa) Vel. Vento (m/s) Dir. Vento (m/s)  \
# 0             1014,7             1014,4              1,5            137,0
# 1             1015,2             1014,7              0,9            122,0
# 2             1015,1             1014,9              1,8            139,0
# 3             1014,9             1014,5              1,2            202,0
# 4             1014,5             1014,0              1,1            225,0
#
#   Raj. Vento (m/s) Radiacao (KJ/m²) Chuva (mm)  Unnamed: 19
# 0              4,0              NaN        0,0          NaN
# 1              4,6              NaN        1,2          NaN
# 2              6,6              NaN        1,6          NaN
# 3              3,8              NaN        0,2          NaN
# 4              2,0              NaN        0,0          NaN

# %%
df.keys()
# Out:
# Index(['Data', 'Hora (UTC)', 'Temp. Ins. (C)', 'Temp. Max. (C)',
#        'Temp. Min. (C)', 'Umi. Ins. (%)', 'Umi. Max. (%)', 'Umi. Min. (%)',
#        'Pto Orvalho Ins. (C)', 'Pto Orvalho Max. (C)', 'Pto Orvalho Min. (C)',
#        'Pressao Ins. (hPa)', 'Pressao Max. (hPa)', 'Pressao Min. (hPa)',
#        'Vel. Vento (m/s)', 'Dir. Vento (m/s)', 'Raj. Vento (m/s)',
#        'Radiacao (KJ/m²)', 'Chuva (mm)', 'Unnamed: 19'],
#       dtype='object')

# %%
df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv', skiprows=1, delimiter=';', decimal=',')

# %%
df['Vel. Vento (m/s)'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Radiacao (KJ/m²)'].plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv', skiprows=1, delimiter=';', decimal=',', index_col=['Data', "Hora (UTC)"])

# %%
df.head()
# Out:
#                        Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# Data       Hora (UTC)
# 01/10/2019 100                   20.9            21.0            20.7
#            200                   20.6            21.0            20.5
#            300                   20.0            20.7            20.0
#            400                   20.0            20.2            20.0
#            500                   19.9            20.0            19.9
#
#                        Umi. Ins. (%)  Umi. Max. (%)  Umi. Min. (%)  \
# Data       Hora (UTC)
# 01/10/2019 100                  95.0           96.0           94.0
#            200                  96.0           96.0           95.0
#            300                  96.0           96.0           96.0
#            400                  96.0           96.0           96.0
#            500                  95.0           96.0           95.0
#
#                        Pto Orvalho Ins. (C)  Pto Orvalho Max. (C)  \
# Data       Hora (UTC)
# 01/10/2019 100                         20.1                  20.2
#            200                         19.9                  20.2
#            300                         19.4                  20.0
#            400                         19.3                  19.6
#            500                         19.1                  19.3
#
#                        Pto Orvalho Min. (C)  Pressao Ins. (hPa)  \
# Data       Hora (UTC)
# 01/10/2019 100                         19.9              1014.7
#            200                         19.8              1015.1
#            300                         19.3              1014.9
#            400                         19.3              1014.5
#            500                         19.1              1014.0
#
#                        Pressao Max. (hPa)  Pressao Min. (hPa)  \
# Data       Hora (UTC)
# 01/10/2019 100                     1014.7              1014.4
#            200                     1015.2              1014.7
#            300                     1015.1              1014.9
#            400                     1014.9              1014.5
#            500                     1014.5              1014.0
#
#                        Vel. Vento (m/s)  Dir. Vento (m/s)  Raj. Vento (m/s)  \
# Data       Hora (UTC)
# 01/10/2019 100                      1.5             137.0               4.0
#            200                      0.9             122.0               4.6
#            300                      1.8             139.0               6.6
#            400                      1.2             202.0               3.8
#            500                      1.1             225.0               2.0
#
#                        Radiacao (KJ/m²)  Chuva (mm)  Unnamed: 19
# Data       Hora (UTC)
# 01/10/2019 100                      NaN         0.0          NaN
#            200                      NaN         1.2          NaN
#            300                      NaN         1.6          NaN
#            400                      NaN         0.2          NaN
#            500                      NaN         0.0          NaN

# %%
df.boxplot('Radiacao (KJ/m²)', by='Hora (UTC)')
# Out:
# <AxesSubplot:title={'center':'Radiacao (KJ/m²)'}, xlabel='Hora (UTC)'>
