# %% [markdown]
# # Analise de dados CSV (Comma-separated values)
#
# * Arquivos de texto que faz ordenação dos dados numa linha, separando os valores por virgulas.
# * Nesta seção iremos trabalhar com o pandas

# %%
# !pip list
# Out:
# Package           Version
# ----------------- --------
# asttokens         2.0.8
# backcall          0.2.0
# cftime            1.6.1
# cycler            0.11.0
# debugpy           1.6.3
# decorator         5.1.1
# entrypoints       0.4
# executing         1.0.0
# fonttools         4.37.1
# ipykernel         6.15.2
# ipython           8.4.0
# jedi              0.18.1
# jupyter_client    7.3.5
# jupyter-core      4.11.1
# kiwisolver        1.4.4
# matplotlib        3.5.3
# matplotlib-inline 0.1.6
# nest-asyncio      1.5.5
# netCDF4           1.6.0
# numpy             1.23.3
# packaging         21.3
# pandas            1.4.4
# parso             0.8.3
# pexpect           4.8.0
# pickleshare       0.7.5
# Pillow            9.2.0
# pip               22.2.2
# prompt-toolkit    3.0.30
# psutil            5.9.1
# ptyprocess        0.7.0
# pure-eval         0.2.2
# Pygments          2.13.0
# pyparsing         3.0.9
# python-dateutil   2.8.2
# pytz              2022.2.1
# pyzmq             23.2.1
# seaborn           0.12.0
# setuptools        63.4.1
# six               1.16.0
# stack-data        0.5.0
# tornado           6.2
# traitlets         5.3.0
# wcwidth           0.2.5
# wheel             0.37.1

# %%
# a forma mais comum de chamar o pandas
import pandas as pd

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/georgynio/Envs/python_aulas/lib/python3.10/site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /home/georgynio/Envs/python_aulas/lib/python3.10/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/georgynio/Envs/python_aulas/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /home/georgynio/Envs/python_aulas/lib/python3.10/site-packages (from pandas) (1.23.3)
# Requirement already satisfied: six>=1.5 in /home/georgynio/Envs/python_aulas/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ## Se tivermos dados e precisamos utilizar algumas funções do Pandas
#
# Precisamos do seguinte:
# * dicionario, listas
# * pandas
#
# A estrutura de um DataFrame:
#
# <img src="./dataframe.webp" width="800">

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45],
  "peso": [70, 65, 50],
  "data": ['26/04/2022', '01/09/2022', '25/12/2022']
}
print(type(data))
# #load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
print(type(df))

# dfinindo o index
df.index = df['data']
print(df)
# Out:
# <class 'dict'>
#    calories  duration  peso        data
# 0       420        50    70  26/04/2022
# 1       380        40    65  01/09/2022
# 2       390        45    50  25/12/2022
# <class 'pandas.core.frame.DataFrame'>
#             calories  duration  peso        data
# data
# 26/04/2022       420        50    70  26/04/2022
# 01/09/2022       380        40    65  01/09/2022
# 25/12/2022       390        45    50  25/12/2022

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
df.plot.bar()
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# <AxesSubplot:>

# %% [markdown]
# ## Carregando um arquivo CSV num DataFrame:

# %%
# não conseguimos porque a linha 1, não é cabeçalho
df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv')
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1253, in TextFileReader.read(self, nrows)
#    1251 nrows = validate_integer("nrows", nrows)
#    1252 try:
# -> 1253     index, columns, col_dict = self._engine.read(nrows)
#    1254 except Exception:
#    1255     self.close()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 3, saw 17

# %%
# pedimos para não ler a primeira linha
# ele não entendeu os dados faltantes
df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv', skiprows=1)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb Cell 10 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # pedimos para não ler a primeira linha
# ----> <a href='vscode-notebook-cell:/home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv', skiprows=1)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1253, in TextFileReader.read(self, nrows)
#    1251 nrows = validate_integer("nrows", nrows)
#    1252 try:
# -> 1253     index, columns, col_dict = self._engine.read(nrows)
#    1254 except Exception:
#    1255     self.close()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 17 fields in line 11, saw 18

# %%
# colocar o tipo de separação
df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv', skiprows=1, delimiter=';')

# %%
df.head()
# Out:
#          Data  Hora (UTC) Temp. Ins. (C) Temp. Max. (C) Temp. Min. (C)  \
# 0  01/10/2019         100           20,9           21,0           20,7
# 1  01/10/2019         200           20,6           21,0           20,5
# 2  01/10/2019         300           20,0           20,7           20,0
# 3  01/10/2019         400           20,0           20,2           20,0
# 4  01/10/2019         500           19,9           20,0           19,9
#
#   Umi. Ins. (%) Umi. Max. (%) Umi. Min. (%) Pto Orvalho Ins. (C)  \
# 0          95,0          96,0          94,0                 20,1
# 1          96,0          96,0          95,0                 19,9
# 2          96,0          96,0          96,0                 19,4
# 3          96,0          96,0          96,0                 19,3
# 4          95,0          96,0          95,0                 19,1
#
#   Pto Orvalho Max. (C) Pto Orvalho Min. (C) Pressao Ins. (hPa)  \
# 0                 20,2                 19,9             1014,7
# 1                 20,2                 19,8             1015,1
# 2                 20,0                 19,3             1014,9
# 3                 19,6                 19,3             1014,5
# 4                 19,3                 19,1             1014,0
#
#   Pressao Max. (hPa) Pressao Min. (hPa) Vel. Vento (m/s) Dir. Vento (m/s)  \
# 0             1014,7             1014,4              1,5            137,0
# 1             1015,2             1014,7              0,9            122,0
# 2             1015,1             1014,9              1,8            139,0
# 3             1014,9             1014,5              1,2            202,0
# 4             1014,5             1014,0              1,1            225,0
#
#   Raj. Vento (m/s) Radiacao (KJ/m²) Chuva (mm)  Unnamed: 19
# 0              4,0              NaN        0,0          NaN
# 1              4,6              NaN        1,2          NaN
# 2              6,6              NaN        1,6          NaN
# 3              3,8              NaN        0,2          NaN
# 4              2,0              NaN        0,0          NaN

# %%
df.tail()
# Out:
#            Data  Hora (UTC) Temp. Ins. (C) Temp. Max. (C) Temp. Min. (C)  \
# 738  31/10/2019        1900           28,3           28,6           27,9
# 739  31/10/2019        2000           26,9           28,3           26,9
# 740  31/10/2019        2100           25,6           26,9           25,6
# 741  31/10/2019        2200           25,0           25,6           25,0
# 742  31/10/2019        2300           24,8           25,0           24,7
#
#     Umi. Ins. (%) Umi. Max. (%) Umi. Min. (%) Pto Orvalho Ins. (C)  \
# 738          69,0          70,0          68,0                 22,1
# 739          73,0          73,0          68,0                 21,6
# 740          78,0          78,0          73,0                 21,4
# 741          82,0          82,0          78,0                 21,6
# 742          82,0          83,0          82,0                 21,5
#
#     Pto Orvalho Max. (C) Pto Orvalho Min. (C) Pressao Ins. (hPa)  \
# 738                 22,2                 21,8             1008,5
# 739                 22,0                 21,5             1008,4
# 740                 21,6                 21,3             1008,3
# 741                 21,6                 21,4             1008,9
# 742                 21,7                 21,5             1009,5
#
#     Pressao Max. (hPa) Pressao Min. (hPa) Vel. Vento (m/s) Dir. Vento (m/s)  \
# 738             1008,9             1008,4              4,9             57,0
# 739             1008,8             1008,3              5,2             45,0
# 740             1008,5             1008,2              5,1             40,0
# 741             1008,9             1008,3              3,6             28,0
# 742             1009,5             1008,9              3,3             29,0
#
#     Raj. Vento (m/s) Radiacao (KJ/m²) Chuva (mm)  Unnamed: 19
# 738             12,8          1769,24        0,0          NaN
# 739             10,6           833,47        0,0          NaN
# 740              9,9            39,70        0,0          NaN
# 741              8,1              NaN        0,0          NaN
# 742              6,8              NaN        0,0          NaN

# %%
df.keys()
# Out:
# Index(['Data', 'Hora (UTC)', 'Temp. Ins. (C)', 'Temp. Max. (C)',
#        'Temp. Min. (C)', 'Umi. Ins. (%)', 'Umi. Max. (%)', 'Umi. Min. (%)',
#        'Pto Orvalho Ins. (C)', 'Pto Orvalho Max. (C)', 'Pto Orvalho Min. (C)',
#        'Pressao Ins. (hPa)', 'Pressao Max. (hPa)', 'Pressao Min. (hPa)',
#        'Vel. Vento (m/s)', 'Dir. Vento (m/s)', 'Raj. Vento (m/s)',
#        'Radiacao (KJ/m²)', 'Chuva (mm)', 'Unnamed: 19'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Data', 'Hora (UTC)', 'Temp. Ins. (C)', 'Temp. Max. (C)',
#        'Temp. Min. (C)', 'Umi. Ins. (%)', 'Umi. Max. (%)', 'Umi. Min. (%)',
#        'Pto Orvalho Ins. (C)', 'Pto Orvalho Max. (C)', 'Pto Orvalho Min. (C)',
#        'Pressao Ins. (hPa)', 'Pressao Max. (hPa)', 'Pressao Min. (hPa)',
#        'Vel. Vento (m/s)', 'Dir. Vento (m/s)', 'Raj. Vento (m/s)',
#        'Radiacao (KJ/m²)', 'Chuva (mm)', 'Unnamed: 19'],
#       dtype='object')

# %%
df['Vel. Vento (m/s)'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> df['Vel. Vento (m/s)'].plot()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/plotting/_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:327, in MPLPlot.generate(self)
#     325 def generate(self):
#     326     self._args_adjust()
# --> 327     self._compute_plot_data()
#     328     self._setup_subplots()
#     329     self._make_plot()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:506, in MPLPlot._compute_plot_data(self)
#     504 # no non-numeric frames or series allowed
#     505 if is_empty:
# --> 506     raise TypeError("no numeric data to plot")
#     508 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
# indicamos o tipo de separador decimal
df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv', skiprows=1, delimiter=';', decimal=',')

# %%
df.head()
# Out:
#          Data  Hora (UTC)  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# 0  01/10/2019         100            20.9            21.0            20.7
# 1  01/10/2019         200            20.6            21.0            20.5
# 2  01/10/2019         300            20.0            20.7            20.0
# 3  01/10/2019         400            20.0            20.2            20.0
# 4  01/10/2019         500            19.9            20.0            19.9
#
#    Umi. Ins. (%)  Umi. Max. (%)  Umi. Min. (%)  Pto Orvalho Ins. (C)  \
# 0           95.0           96.0           94.0                  20.1
# 1           96.0           96.0           95.0                  19.9
# 2           96.0           96.0           96.0                  19.4
# 3           96.0           96.0           96.0                  19.3
# 4           95.0           96.0           95.0                  19.1
#
#    Pto Orvalho Max. (C)  Pto Orvalho Min. (C)  Pressao Ins. (hPa)  \
# 0                  20.2                  19.9              1014.7
# 1                  20.2                  19.8              1015.1
# 2                  20.0                  19.3              1014.9
# 3                  19.6                  19.3              1014.5
# 4                  19.3                  19.1              1014.0
#
#    Pressao Max. (hPa)  Pressao Min. (hPa)  Vel. Vento (m/s)  Dir. Vento (m/s)  \
# 0              1014.7              1014.4               1.5             137.0
# 1              1015.2              1014.7               0.9             122.0
# 2              1015.1              1014.9               1.8             139.0
# 3              1014.9              1014.5               1.2             202.0
# 4              1014.5              1014.0               1.1             225.0
#
#    Raj. Vento (m/s)  Radiacao (KJ/m²)  Chuva (mm)  Unnamed: 19
# 0               4.0               NaN         0.0          NaN
# 1               4.6               NaN         1.2          NaN
# 2               6.6               NaN         1.6          NaN
# 3               3.8               NaN         0.2          NaN
# 4               2.0               NaN         0.0          NaN

# %%
df
# Out:
#            Data  Hora (UTC)  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# 0    01/10/2019         100            20.9            21.0            20.7
# 1    01/10/2019         200            20.6            21.0            20.5
# 2    01/10/2019         300            20.0            20.7            20.0
# 3    01/10/2019         400            20.0            20.2            20.0
# 4    01/10/2019         500            19.9            20.0            19.9
# ..          ...         ...             ...             ...             ...
# 738  31/10/2019        1900            28.3            28.6            27.9
# 739  31/10/2019        2000            26.9            28.3            26.9
# 740  31/10/2019        2100            25.6            26.9            25.6
# 741  31/10/2019        2200            25.0            25.6            25.0
# 742  31/10/2019        2300            24.8            25.0            24.7
#
#      Umi. Ins. (%)  Umi. Max. (%)  Umi. Min. (%)  Pto Orvalho Ins. (C)  \
# 0             95.0           96.0           94.0                  20.1
# 1             96.0           96.0           95.0                  19.9
# 2             96.0           96.0           96.0                  19.4
# 3             96.0           96.0           96.0                  19.3
# 4             95.0           96.0           95.0                  19.1
# ..             ...            ...            ...                   ...
# 738           69.0           70.0           68.0                  22.1
# 739           73.0           73.0           68.0                  21.6
# 740           78.0           78.0           73.0                  21.4
# 741           82.0           82.0           78.0                  21.6
# 742           82.0           83.0           82.0                  21.5
#
#      Pto Orvalho Max. (C)  Pto Orvalho Min. (C)  Pressao Ins. (hPa)  \
# 0                    20.2                  19.9              1014.7
# 1                    20.2                  19.8              1015.1
# 2                    20.0                  19.3              1014.9
# 3                    19.6                  19.3              1014.5
# 4                    19.3                  19.1              1014.0
# ..                    ...                   ...                 ...
# 738                  22.2                  21.8              1008.5
# 739                  22.0                  21.5              1008.4
# 740                  21.6                  21.3              1008.3
# 741                  21.6                  21.4              1008.9
# 742                  21.7                  21.5              1009.5
#
#      Pressao Max. (hPa)  Pressao Min. (hPa)  Vel. Vento (m/s)  \
# 0                1014.7              1014.4               1.5
# 1                1015.2              1014.7               0.9
# 2                1015.1              1014.9               1.8
# 3                1014.9              1014.5               1.2
# 4                1014.5              1014.0               1.1
# ..                  ...                 ...               ...
# 738              1008.9              1008.4               4.9
# 739              1008.8              1008.3               5.2
# 740              1008.5              1008.2               5.1
# 741              1008.9              1008.3               3.6
# 742              1009.5              1008.9               3.3
#
#      Dir. Vento (m/s)  Raj. Vento (m/s)  Radiacao (KJ/m²)  Chuva (mm)  \
# 0               137.0               4.0               NaN         0.0
# 1               122.0               4.6               NaN         1.2
# 2               139.0               6.6               NaN         1.6
# 3               202.0               3.8               NaN         0.2
# 4               225.0               2.0               NaN         0.0
# ..                ...               ...               ...         ...
# 738              57.0              12.8           1769.24         0.0
# 739              45.0              10.6            833.47         0.0
# 740              40.0               9.9             39.70         0.0
# 741              28.0               8.1               NaN         0.0
# 742              29.0               6.8               NaN         0.0
#
#      Unnamed: 19
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 738          NaN
# 739          NaN
# 740          NaN
# 741          NaN
# 742          NaN
#
# [743 rows x 20 columns]

# %%
df['Vel. Vento (m/s)'][0] + 3
# Out:
# 4.5

# %%
df['Vel. Vento (m/s)'].plot(color='green', legend=True)
# Out:
# <AxesSubplot:>

# %%
df['Radiacao (KJ/m²)'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Data', 'Temp. Ins. (C)'].boxplot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Data', 'Temp. Ins. (C)')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb Cell 22 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/georgynio/Envs/python_aulas/python_aulas/Exercicios/Exemplos_base/dados_csv_2.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> df['Data', 'Temp. Ins. (C)'].boxplot()
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/Envs/python_aulas/lib/python3.10/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: ('Data', 'Temp. Ins. (C)')

# %%
df[['Data', 'Temp. Ins. (C)']].plot()
# Out:
# <AxesSubplot:>

# %%
# definindo index
df = pd.read_csv('./../dados/VILA-VELHA-(A634).csv', skiprows=1, delimiter=';', decimal=',', index_col=['Data', "Hora (UTC)"])

# %%
df.head(40)
# Out:
#                        Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# Data       Hora (UTC)
# 01/10/2019 100                   20.9            21.0            20.7
#            200                   20.6            21.0            20.5
#            300                   20.0            20.7            20.0
#            400                   20.0            20.2            20.0
#            500                   19.9            20.0            19.9
#            600                   19.6            19.9            19.6
#            700                   19.7            19.8            19.6
#            800                   19.3            19.8            19.1
#            900                   19.4            19.6            19.3
#            1000                  19.7            19.7            19.4
#            1100                  20.6            20.7            19.7
#            1200                  22.1            22.1            20.6
#            1300                  23.6            23.9            22.1
#            1400                  23.6            24.3            23.4
#            1500                  23.9            24.0            23.3
#            1600                  25.2            25.4            23.7
#            1700                  24.6            25.2            24.1
#            1800                  23.6            24.6            23.4
#            1900                  22.9            23.6            22.9
#            2000                  22.1            22.9            22.1
#            2100                  21.4            22.1            21.4
#            2200                  21.0            21.4            21.0
#            2300                  20.3            21.1            20.3
# 02/10/2019 0                     20.2            20.6            20.1
#            100                   20.2            20.4            20.1
#            200                   20.0            20.2            19.9
#            300                   19.1            20.0            19.1
#            400                   18.8            19.1            18.7
#            500                   18.6            18.9            18.6
#            600                   18.1            18.7            18.0
#            700                   17.5            18.1            17.5
#            800                   17.1            17.7            17.1
#            900                   17.1            17.2            16.8
#            1000                  20.4            20.4            17.1
#            1100                  22.7            22.7            20.4
#            1200                  24.2            24.3            22.7
#            1300                  25.8            26.0            24.2
#            1200                     1.0             134.0               3.0
#            1300                     2.1              79.0               4.8
#            1400                     1.7              90.0               5.1
#            1500                     1.9             105.0               4.8
#            1600                     1.9             111.0               5.7
#            1700                     1.7             106.0               6.8
#            1800                     2.0             101.0               5.2
#            1900                     1.6             104.0               5.3
#            2000                     1.0              92.0               4.2
#            2100                     0.7              88.0               2.5
#            2200                     0.4             183.0               1.4
#            2300                     0.5             266.0               0.9
# 02/10/2019 0                        1.1             342.0               1.6
#            100                      1.2             284.0               2.4
#            200                      2.4             273.0               3.3
#            300                      1.8             279.0               3.3
#            400                      2.5             270.0               3.6
#            500                      1.1             250.0               3.9
#            600                      0.7             302.0               3.0
#            700                      1.6             293.0               2.9
#            800                      1.4             284.0               2.9
#            900                      1.6             303.0               2.6
#            1000                     1.8             290.0               4.0
#            1100                     1.8             300.0               3.5
#            1200                     1.4             285.0               4.2
#            1300                     1.6             350.0               5.0
#            1400                     1.9             121.0               6.7
#            1500                     2.5             104.0               5.7
#            1600                     1.8             119.0               6.7
#
#                        Radiacao (KJ/m²)  Chuva (mm)  Unnamed: 19
# Data       Hora (UTC)
# 01/10/2019 100                      NaN         0.0          NaN
#            200                      NaN         1.2          NaN
#            300                      NaN         1.6          NaN
#            400                      NaN         0.2          NaN
#            500                      NaN         0.0          NaN
#            600                      NaN         0.0          NaN
#            700                      NaN         0.0          NaN
#            800                      NaN         0.0          NaN
#            900                    24.11         0.0          NaN
#            1000                  190.11         0.0          NaN
#            1100                  509.48         0.0          NaN
#            1200                  739.15         0.0          NaN
#            1300                 1698.37         0.0          NaN
#            1400                 1525.37         0.0          NaN
#            1500                 1040.21         0.0          NaN
#            1600                 2437.72         0.0          NaN
#            1700                 1467.43         0.0          NaN
#            1800                  987.70         0.2          NaN
#            1900                  472.83         0.0          NaN
#            2000                  152.36         0.0          NaN
#            2100                   24.38         0.0          NaN
#            2200                     NaN         0.0          NaN
#            2300                     NaN         0.0          NaN
# 02/10/2019 0                        NaN         0.0          NaN
#            100                      NaN         0.0          NaN
#            200                      NaN         0.0          NaN
#            300                      NaN         0.0          NaN
#            400                      NaN         0.0          NaN
#            500                      NaN         0.0          NaN
#            600                      NaN         0.0          NaN
#            700                      NaN         0.0          NaN
#            800                      NaN         0.0          NaN
#            900                    44.25         0.0          NaN
#            1000                  749.26         0.0          NaN
#            1100                 1660.66         0.0          NaN
#            1200                 2476.83         0.0          NaN
#            1300                 3100.93         0.0          NaN
#            1400                 3494.24         0.0          NaN
#            1500                 3615.45         0.0          NaN
#            1600                 3478.26         0.0          NaN

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(18, 6))
df.boxplot('Radiacao (KJ/m²)', by='Hora (UTC)')
plt.ylabel('Radiacao (KJ/m²)')
plt.title('Radiação solar')
# Out:
# Text(0.5, 1.0, 'Radiação solar')

# %%
df['Temp. Ins. (C)'].describe()
# Out:
# count    743.000000
# mean      24.179139
# std        3.026720
# min       17.100000
# 25%       21.950000
# 50%       23.800000
# 75%       26.300000
# max       33.600000
# Name: Temp. Ins. (C), dtype: float64
